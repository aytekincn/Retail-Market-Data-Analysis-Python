# %%
import pandas as pd

# %%
retailMarket  = pd.read_csv("C:\\Users\\aytek\\Downloads\\Portfolio\\SampleSuperstore.csv")

# %% [markdown]
# # Overwiev of data

# %%
retailMarket
# Out:
#         Segment             City       State Region         Category  \
# 0      Consumer        Henderson    Kentucky  South        Furniture
# 1      Consumer        Henderson    Kentucky  South        Furniture
# 2     Corporate      Los Angeles  California   West  Office Supplies
# 3      Consumer  Fort Lauderdale     Florida  South        Furniture
# 4      Consumer  Fort Lauderdale     Florida  South  Office Supplies
# ...         ...              ...         ...    ...              ...
# 9989   Consumer            Miami     Florida  South        Furniture
# 9990   Consumer       Costa Mesa  California   West        Furniture
# 9991   Consumer       Costa Mesa  California   West       Technology
# 9992   Consumer       Costa Mesa  California   West  Office Supplies
# 9993   Consumer      Westminster  California   West  Office Supplies
#
#      Sub_Category     Sales  Quantity    Profit
# 0       Bookcases  261.9600         2   41.9136
# ...

# %% [markdown]
# # How many Category and Sub Category are there?

# %%
retailMarket["Category"].nunique() , retailMarket["Sub_Category"].nunique()
# Out:
# (3, 17)

# %% [markdown]
# # How many State and City are there?

# %%
retailMarket["State"].nunique(), retailMarket["City"].nunique()
# Out:
# (49, 531)

# %% [markdown]
# # How many sales by state?

# %%
retailMarket["State"].value_counts()
# Out:
# California              1951
# New York                1099
# Texas                    975
# Pennsylvania             571
# Washington               499
# Illinois                 488
# Ohio                     467
# Florida                  383
# Michigan                 253
# North Carolina           249
# Arizona                  224
# Virginia                 223
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 138
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %% [markdown]
# # İnformation about the highest sale?

# %%
retailMarket[ retailMarket["Sales"] == retailMarket["Sales"].max()]
# Out:
#           Segment          City    State Region    Category Sub_Category  \
# 2697  Home Office  Jacksonville  Florida  South  Technology     Machines
#
#          Sales  Quantity     Profit
# 2697  22638.48         6 -1811.0784

# %% [markdown]
# # Information about the minimum sales?

# %%
retailMarket[ retailMarket["Sales"] == retailMarket["Sales"].min()]
# Out:
#        Segment     City  State   Region         Category Sub_Category  Sales  \
# 4101  Consumer  Houston  Texas  Central  Office Supplies   Appliances  0.444
#
#       Quantity  Profit
# 4101         1   -1.11

# %% [markdown]
# ## Average of sales by sub category?

# %%
retailMarket.groupby("Sub_Category").mean("Sales")
# Out:
#                     Sales  Quantity      Profit
# Sub_Category
# Accessories    216.680443  3.847150   54.286535
# Appliances     231.244320  3.713978   39.005508
# Art             34.215517  3.772554    8.223342
# Binders        133.972979  3.931171   19.796290
# Bookcases      505.163404  3.818584  -15.038735
# Chairs         533.619072  3.828431   43.557920
# Copiers       2198.941618  3.441176  817.909190
# Envelopes       65.003328  3.565217   27.467203
# Fasteners       13.981185  4.217593    4.391895
# Furnishings     96.191210  3.725840   13.684473
# Labels          34.552546  3.861972   15.335387
# Machines      1645.553313  3.826087   29.432669
# Paper           58.755879  3.814220   25.488103
# Phones         371.117779  3.700565   50.036125
# Storage        263.799914  3.735714   25.725888
# Supplies       246.659460  3.396825   -6.372865
# Tables         650.639382  3.886435  -55.490355

# %% [markdown]
# # Maximum 5 profit information?

# %%
top_5_profits = retailMarket.nlargest(5, "Profit")
top_5_profits
# Out:
#         Segment         City       State   Region         Category  \
# 6826  Corporate    Lafayette     Indiana  Central       Technology
# 8153   Consumer      Seattle  Washington     West       Technology
# 4190   Consumer       Newark    Delaware     East       Technology
# 9039   Consumer      Detroit    Michigan  Central  Office Supplies
# 4098   Consumer  Minneapolis   Minnesota  Central  Office Supplies
#
#      Sub_Category     Sales  Quantity     Profit
# 6826      Copiers  17499.95         5  8399.9760
# 8153      Copiers  13999.96         4  6719.9808
# 4190      Copiers  10499.97         3  5039.9856
# 9039      Binders   9892.74        13  4946.3700
# 4098      Binders   9449.95         5  4630.4755

# %% [markdown]
# # The sum of the sales figures of each product?

# %%
retailMarket.groupby('Sub_Category')["Sales"].sum()
# Out:
# Sub_Category
# Accessories    167277.3020
# Appliances     107528.6090
# Art             26927.6120
# Binders        202433.1710
# Bookcases      114166.9293
# Chairs         326574.8720
# Copiers        149528.0300
# Envelopes       16445.8420
# Fasteners        3019.9360
# Furnishings     91574.0320
# Labels          12266.1540
# Machines       189238.6310
# Paper           76852.6900
# Phones         328439.2340
# Storage        221591.9280
# Supplies        46618.6380
# Tables         206252.6840
# Name: Sales, dtype: float64

# %% [markdown]
# # Data visualization

# %%
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %%
retailMarket.plot(x="State", y=["Sales"])
retailMarket.plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Sales', data=retailMarket)
plt.xticks(rotation=45)
plt.title('Category Sales')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Sub_Category', y='Sales', data=retailMarket)
plt.title('Sub Category Sales')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.barplot(x='State', y='Profit', data=retailMarket)
plt.xticks(rotation=45)
plt.title('Profits by State')
plt.tight_layout()
plt.show()
